# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyansh273/Football-Scouting/blob/main/Player_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files = files.upload()
# Out:
#      <input type="file" id="files-ecf841b1-3ae6-4611-b916-89e53e587cba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ecf841b1-3ae6-4611-b916-89e53e587cba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving all_players_stats.csv to all_players_stats.csv

# %%
from google.colab import files
files = files.upload()
# Out:
#      <input type="file" id="files-fee34a47-b3c8-465c-a41a-942487f39d56" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fee34a47-b3c8-465c-a41a-942487f39d56">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving players_value.csv to players_value.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
player_stats = pd.read_csv("all_players_stats.csv")
player_stats.drop("Unnamed: 0", axis=1, inplace=True)
player_stats.head(1)
# Out:
#                 player nationality  ... gca_og_for          League
# 0  Patrick van Aanholt      nl NED  ...        0.0  Premier-League
#
# [1 rows x 126 columns]

# %%
player_value = pd.read_csv("players_value.csv")
player_value.drop("Unnamed: 0", axis=1, inplace=True)
player_value.head(1)
# Out:
#              Name Field Position  Age  Market Value (Millions)
# 0  Pedro Henrique    Left Winger   31                     1.08

# %%
player_stats = player_stats.merge(player_value, how='left', left_on="player", right_on="Name").drop(["Name","Age"], axis=1)
player_stats.head(1)
# Out:
#                 player nationality  ... Field Position Market Value (Millions)
# 0  Patrick van Aanholt      nl NED  ...      Left-Back                     6.3
#
# [1 rows x 128 columns]

# %%
player_stats[player_stats["Field Position"]=="Centre-Forward"]
player_stats[player_stats.player.str.contains("Kane")]
# Out:
#          player nationality  ...  Field Position Market Value (Millions)
# 246  Harry Kane     eng ENG  ...  Centre-Forward                   108.0
#
# [1 rows x 128 columns]

# %%
player_stats.describe()
# Out:
#                age   birth_year  ...   gca_og_for  Market Value (Millions)
# count  2895.000000  2895.000000  ...  2893.000000              2243.000000
# mean     25.317098  1994.343351  ...     0.074317                 9.758744
# std       4.649531     4.655466  ...     0.285072                13.881569
# min      14.000000  1977.000000  ...     0.000000                 0.045000
# 25%      22.000000  1991.000000  ...     0.000000                 1.800000
# 50%      25.000000  1995.000000  ...     0.000000                 4.500000
# 75%      29.000000  1998.000000  ...     0.000000                11.700000
# max      42.000000  2005.000000  ...     3.000000               144.000000
#
# [8 rows x 122 columns]

# %%
player_stats2 = player_stats.copy()
cols = player_stats2.columns[26:len(player_stats2.columns)-4]
for i in range(len(cols)):
  if ('per90' in cols[i]) or ('pct' in cols[i]):
    continue
  else:
    player_stats2[cols[i]+"_per90"] = player_stats2[cols[i]]/player_stats2["minutes_90s"]
    player_stats2.drop(cols[i], axis=1, inplace=True)
player_stats2.head(2)
# Out:
#                 player nationality  ... gca_shots_per90 gca_fouled_per90
# 0  Patrick van Aanholt      nl NED  ...             0.0         0.000000
# 1        Tammy Abraham     eng ENG  ...             0.0         0.086207
#
# [2 rows x 124 columns]

# %%
player_stats2 = player_stats2.loc[player_stats2.games_starts>10]
player_stats2.head(2)
# Out:
#                 player nationality  ... gca_shots_per90 gca_fouled_per90
# 0  Patrick van Aanholt      nl NED  ...             0.0         0.000000
# 1        Tammy Abraham     eng ENG  ...             0.0         0.086207
#
# [2 rows x 124 columns]

# %%
req_cols = ["player"]+player_stats2.columns[np.arange(26,len(player_stats2.columns))].tolist()
req_cols = [i for i in req_cols if i not in ["League","Field Position", "Market Value (Millions)"]]
forwards_cluster_data = player_stats2.loc[player_stats2["Field Position"] == "Centre-Forward", req_cols]
forwards_cluster_data.shape
# Out:
# (178, 96)

# %%
forwards_cluster_data = forwards_cluster_data[~forwards_cluster_data.isin([np.nan, np.inf, -np.inf]).any(1)]

# %%
y = forwards_cluster_data["player"]
X = forwards_cluster_data.drop("player", axis=1)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans

# %%
errors = []
for i in range(1,11):
  kmeans = KMeans(n_clusters=i, random_state=52)
  kmeans.fit(X_scaled)
  errors.append(kmeans.inertia_) 
  forwards_cluster_data["cluster_"+str(i)] = kmeans.labels_.tolist()

# %%
fig, ax = plt.subplots()
ax.plot(errors)

# %%
errors
# Out:
# [467.6750419031725,
#  389.8290851719453,
#  331.86912119219915,
#  304.8372688154914,
#  291.8429069683308,
#  280.2113917011448,
#  268.40428717126355,
#  265.0510769367244,
#  258.0412236812929,
#  253.3808691397578]

# %%
forwards_cluster_data.groupby("cluster_8").size()
# Out:
# cluster_8
# 0    28
# 1    17
# 2    25
# 3     5
# 4     5
# 5    24
# 6    48
# 7    24
# dtype: int64

# %%
errors = []
for i in range(1,100):
  kmeans = KMeans(n_clusters=8)
  kmeans.fit(X_scaled)
  errors.append(kmeans.inertia_)

# %%
fig, ax = plt.subplots()
ax.plot(errors)

# %%
forwards_cluster_data.groupby(["cluster_8"])['xg_per90', 'xa_per90','shots_total_per90','shots_on_target_per90', 'passes_pct_short', 'passes_pct_medium', 'passes_pct_long','sca_per90','gca_per90','tackles_per90', 'blocks_per90', 'clearances_per90'].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#            xg_per90  xa_per90  ...  blocks_per90  clearances_per90
# cluster_8                      ...
# 0          0.272143  0.094286  ...      1.305843          0.926455
# 1          0.558824  0.181765  ...      0.735789          0.554249
# 2          0.278400  0.059600  ...      0.676928          0.687666
# 3          0.756000  0.292000  ...      0.615258          0.281074
# 4          0.042000  0.072000  ...      1.667951          2.829051
# 5          0.462500  0.132500  ...      0.790183          0.585273
# 6          0.432500  0.099375  ...      0.688709          0.770334
# 7          0.335000  0.167917  ...      1.065548          0.538371
#
# [8 rows x 12 columns]

# %%
cluster_stats = forwards_cluster_data.loc[forwards_cluster_data.cluster_8==1,['player','xg_per90', 'xa_per90','shots_total_per90','shots_on_target_per90', 'passes_pct_short', 'passes_pct_medium', 'passes_pct_long','sca_per90','gca_per90','tackles_per90', 'blocks_per90', 'clearances_per90']]
cluster_stats.set_index("player", inplace=True)
cluster_stats.head(5)
# Out:
#                    xg_per90  xa_per90  ...  blocks_per90  clearances_per90
# player                                 ...
# Michail Antonio        0.52      0.11  ...      1.141553          0.365297
# Harry Kane             0.60      0.22  ...      0.877193          1.198830
# Anthony Martial        0.40      0.12  ...      1.341463          0.548780
# Timo Werner            0.41      0.21  ...      0.830450          0.138408
# Wissam Ben Yedder      0.66      0.22  ...      0.655172          0.137931
#
# [5 rows x 12 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = MinMaxScaler()
cluster_stats_std = scaler.fit_transform(cluster_stats)
cluster_stats_std = pd.DataFrame(cluster_stats_std, columns = cluster_stats.columns)
cluster_stats_std.set_index(cluster_stats.index.values, inplace=True)
cluster_stats_std.head(2)
# Out:
#                  xg_per90  xa_per90  ...  blocks_per90  clearances_per90
# Michail Antonio  0.255814  0.263158  ...      0.802419          0.214314
# Harry Kane       0.348837  0.842105  ...      0.541141          1.000000
#
# [2 rows x 12 columns]

# %%
fig = px.line_polar(
                    r=cluster_stats_std.iloc[1].values,
                    theta=cluster_stats_std.columns,
                    line_close=True,
                    range_r = [0,1.0])
fig.update_traces(fill='toself')
fig.show()

# %%
fig = go.Figure()
for i in [1,15]:
    fig.add_trace(go.Scatterpolar(r=cluster_stats_std.iloc[i].values,theta=cluster_stats_std.columns,fill='toself',name=cluster_stats_std.index.values[i],showlegend=True,))
fig.update_layout(polar=dict(radialaxis=dict(visible=True,range=[0, 1])),title="Player Comparison")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e1e4921a-bea9-467d-b3f6-9919bbd62b9f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e1e4921a-bea9-467d-b3f6-9919bbd62b9f")) {
#                     Plotly.newPlot(
#                         'e1e4921a-bea9-467d-b3f6-9919bbd62b9f',
#                         [{"fill": "toself", "name": "Harry Kane", "r": [0.3488372093023256, 0.8421052631578947, 0.700731171793396, 0.476264189886481, 0.30625000000000036, 0.5568627450980395, 0.33333333333333326, 0.6324998577921634, 0.7663787916327467, 0.3541335938454024, 0.5411409317996978, 1.0000000000000002], "showlegend": true, "theta": ["xg_per90", "xa_per90", "shots_total_per90", "shots_on_target_per90", "passes_pct_short", "passes_pct_medium", "passes_pct_long", "sca_per90", "gca_per90", "tackles_per90", "blocks_per90", "clearances_per90"], "type": "scatterpolar"}, {"fill": "toself", "name": "Duv\u00e1n Zapata", "r": [0.3255813953488372, 1.0, 0.6276648624765273, 0.5266446959333417, 0.6624999999999996, 0.776470588235294, 0.10333333333333328, 0.9729075149042987, 0.41816959100079476, 0.18420867608802644, 0.5352297812562712, 0.5126661021928083], "showlegend": true, "theta": ["xg_per90", "xa_per90", "shots_total_per90", "shots_on_target_per90", "passes_pct_short", "passes_pct_medium", "passes_pct_long", "sca_per90", "gca_per90", "tackles_per90", "blocks_per90", "clearances_per90"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [0, 1], "visible": true}}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "sca ...

# %%
player_stats2 = player_stats2.merge(forwards_cluster_data[["player","cluster_8"]], how='left', on="player")

# %%
player_stats2.rename(columns = {"cluster_8":"fw_cluster"}, inplace=True)

# %%
player_alt_stats = player_stats2[player_stats2.fw_cluster == player_stats2.loc[player_stats2.player.str.contains("Kane"),"fw_cluster"].tolist()[0]].sort_values("goals_assists_pens_per90", ascending=False)
player_alt_stats.head()
# Out:
#                   player nationality  ... gca_fouled_per90 fw_cluster
# 799   Robert Lewandowski      pl POL  ...         0.073260        2.0
# 144           Harry Kane     eng ENG  ...         0.087719        2.0
# 880          André Silva      pt POR  ...         0.130293        2.0
# 1086       Romelu Lukaku      be BEL  ...         0.000000        2.0
# 420          Andy Delort      dz ALG  ...         0.036232        2.0
#
# [5 rows x 123 columns]

# %%
player_alt_stats.to_csv("kane_alts.csv")

# %%
from google.colab import files
files.download("kane_alts.csv")

# %%
player_stats2[player_stats2.position.str.contains("MF")]
# Out:
#                    player nationality  ... gca_shots_per90 gca_fouled_per90
# 11       Thiago Alcántara      es ESP  ...        0.000000         0.000000
# 17                  Allan      br BRA  ...        0.000000         0.000000
# 19         Miguel Almirón      py PAR  ...        0.037037         0.000000
# 23           Ethan Ampadu     wls WAL  ...        0.000000         0.000000
# 29       Stuart Armstrong     sct SCO  ...        0.097720         0.065147
# ...                   ...         ...  ...             ...              ...
# 2796  Unai Vencedor Paris      es ESP  ...        0.000000         0.000000
# 2798          Mikel Vesga      es ESP  ...        0.052356         0.000000
# 2809      Nikola Vukčević      me MNE  ...        0.000000         0.000000
# 2810          Daniel Wass      dk DEN  ...        0.000000         0.000000
# 2821     Martín Zubimendi      es ESP  ...        0.000000         0.000000
#
# [671 rows x 122 columns]
